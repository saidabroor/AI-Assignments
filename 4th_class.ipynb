# %% [markdown]
# # Drop

# %%
import pandas as pd

# %%
df = pd.read_csv('telefon turini aniqlash2.csv')

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis',yticklabels=False)
plt.show()

# %%
import missingno as msno
msno.matrix(df)
plt.show()

# %%
df.isnull().sum()  #tushib qolgan qiymatlarni aniqlash
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
#bir element bilash ishlash uchun yoziladigan kod

df['tel_ingichgaligi']
# Out:
# 0       0.6
# 1       0.7
# 2       0.9
# 3       0.8
# 4       0.6
#        ...
# 1996    0.8
# 1997    0.2
# 1998    0.7
# 1999    0.1
# 2000    0.9
# Name: tel_ingichgaligi, Length: 2001, dtype: float64

# %%
df=df.dropna(subset=['tel_ingichgaligi'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1998 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                1998 non-null   int64
#  1   blutus                         1998 non-null   int64
#  2   protsessor_tezligi             1998 non-null   float64
#  3   ikkita simkartalik             1998 non-null   int64
#  4   Oldi_kamera                    1998 non-null   int64
#  5   4G                             1998 non-null   int64
#  6   Ichki_xotira                   1998 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          1998 non-null   object
#  9   Vazni                          1998 non-null   int64
#  10  Protsessor yadrolari soni      1997 non-null   float64
#  11  Asosiy kamera                  1996 non-null   float64
# ...

# %%
df=df.dropna(subset=['Rangi'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1998 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                1998 non-null   int64
#  1   blutus                         1998 non-null   int64
#  2   protsessor_tezligi             1998 non-null   float64
#  3   ikkita simkartalik             1998 non-null   int64
#  4   Oldi_kamera                    1998 non-null   int64
#  5   4G                             1998 non-null   int64
#  6   Ichki_xotira                   1998 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          1998 non-null   object
#  9   Vazni                          1998 non-null   int64
#  10  Protsessor yadrolari soni      1997 non-null   float64
#  11  Asosiy kamera                  1996 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1998 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                1998 non-null   int64
#  1   blutus                         1998 non-null   int64
#  2   protsessor_tezligi             1998 non-null   float64
#  3   ikkita simkartalik             1998 non-null   int64
#  4   Oldi_kamera                    1998 non-null   int64
#  5   4G                             1998 non-null   int64
#  6   Ichki_xotira                   1998 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          1998 non-null   object
#  9   Vazni                          1998 non-null   int64
#  10  Protsessor yadrolari soni      1997 non-null   float64
#  11  Asosiy kamera                  1996 non-null   float64
# ...

# %%
# Umumumiy kod

tushib_qolganlar=df.columns[df.isnull().any()]
tushib_qolganlar
# Out:
# Index(['Protsessor yadrolari soni', 'Asosiy kamera', 'Qurilma xajmi(pix)',
#        'Qurilma ekran kengligi(pix)', 'Qurilma xajmi(cm)',
#        'Qurilma ekran kengligi(cm)', 'Qurilma xajmi(pix).1'],
#       dtype='object')

# %%
df=df.dropna(subset=tushib_qolganlar)

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    0
# Qurilma xajmi(pix)               0
# Qurilma ekran kengligi(pix)      0
# ram                              0
# Qurilma xajmi(cm)                0
# Qurilma ekran kengligi(cm)       0
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             0
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64
