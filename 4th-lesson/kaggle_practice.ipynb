# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import missingno as msno
import random

# %%
df = pd.read_csv(r'C:\Users\Saidabrorkhon\ML_Lectures\global_shark_attacks.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6890 entries, 0 to 6889
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       6587 non-null   object
#  1   year       6758 non-null   float64
#  2   type       6871 non-null   object
#  3   country    6839 non-null   object
#  4   area       6409 non-null   object
#  5   location   6325 non-null   object
#  6   activity   6304 non-null   object
#  7   name       6670 non-null   object
#  8   sex        6318 non-null   object
#  9   age        3903 non-null   object
#  10  fatal_y_n  6890 non-null   object
#  11  time       3372 non-null   object
#  12  species    3772 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 699.9+ KB

# %%
df.head()
# Out:
#          date    year        type    country                area  \
# 0  2023-05-13  2023.0  Unprovoked  AUSTRALIA     South Australia
# 1  2023-04-29  2023.0  Unprovoked  AUSTRALIA   Western Australia
# 2  2022-10-07  2022.0  Unprovoked  AUSTRALIA  Western  Australia
# 3  2021-10-04  2021.0  Unprovoked        USA             Florida
# 4  2021-10-03  2021.0  Unprovoked        USA             Florida
#
#                                    location      activity                name  \
# 0                                  Elliston       Surfing    Simon Baccanello
# 1                      Yallingup, Busselton      Swimming                male
# 2                              Port Hedland  Spearfishing         Robbie Peck
# 3  Fort Pierce State Park, St. Lucie County       Surfing  Truman Van Patrick
# 4               Jensen Beach, Martin County      Swimming                male
#
#   sex   age fatal_y_n   time      species
# 0   M    46         Y  10h10  White shark
# 1   M   NaN         N  11h20     1m shark
# 2   M    38         N  11h30   Bull shark
# 3   M  25.0         N    NaN          NaN
# 4   M   NaN         N  12h00          NaN

# %%
df.tail()
# Out:
#      date  year          type       country               area  \
# 6885  NaN   NaN  Sea Disaster        GREECE       Off Thessaly
# 6886  NaN   NaN    Unprovoked     INDONESIA      Riau Province
# 6887  NaN   NaN    Unprovoked          IRAQ             Basrah
# 6888  NaN   NaN    Unprovoked  SOUTH AFRICA      KwaZulu-Natal
# 6889  NaN   NaN    Unprovoked     AUSTRALIA  Western Australia
#
#                                                location  \
# 6885                                                NaN
# 6886  Natuna Islands, between Sumatra & Kalimantan i...
# 6887        Shatt-el Arab River near a small boat stand
# 6888                                             Durban
# 6889                                                NaN
#
#                                          activity               name sex  \
# 6885                    Shipwrecked Persian Fleet              males   M
# 6886                  Swimming near anchored ship  a ship's engineer   M
# 6887                                     Swimming               male   M
# 6888  Crew swimming alongside their anchored ship               male   M
# 6889                                 Pearl diving              Ahmun   M
#
#            age fatal_y_n       time     species
# 6885       NaN         Y        NaN         NaN
# 6886       NaN         Y        NaN         NaN
# 6887  13 or 14         Y  Afternoon  Bull shark
# 6888       NaN         Y        NaN         NaN
# 6889       NaN         Y        NaN         NaN

# %%
df.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'area', 'location', 'activity',
#        'name', 'sex', 'age', 'fatal_y_n', 'time', 'species'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['date',
#  'year',
#  'type',
#  'country',
#  'area',
#  'location',
#  'activity',
#  'name',
#  'sex',
#  'age',
#  'fatal_y_n',
#  'time',
#  'species']

# %%
df['sex']
# Out:
# 0       M
# 1       M
# 2       M
# 3       M
# 4       M
#        ..
# 6885    M
# 6886    M
# 6887    M
# 6888    M
# 6889    M
# Name: sex, Length: 6890, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# M        5545
# F         768
# N           2
# .           1
# M x 2       1
# lli         1
# Name: count, dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# New Smyrna Beach, Volusia County                                       192
# Daytona Beach, Volusia County                                           34
# Ponce Inlet, Volusia County                                             26
# Myrtle Beach, Horry County                                              21
# Melbourne Beach, Brevard County                                         21
#                                                                       ...
# St. Thomé                                                                1
# Uo, Lahaina, Maui                                                        1
# On the Thames River                                                      1
# Natuna Islands, between Sumatra & Kalimantan in the South China Sea      1
# Melaleuca Beach, Cowaramup Bay, Gracetown,                               1
# Name: count, Length: 4427, dtype: int64

# %%
#statsitik tahlil qilish

df.describe()
# Out:
#               year
# count  6758.000000
# mean   1970.935928
# std      56.227881
# min       1.000000
# 25%    1950.000000
# 50%    1986.000000
# 75%    2009.000000
# max    2023.000000

# %%
# tushib qolgan qiymatlarni aniqlash

df.isnull().sum()
# Out:
# date          303
# year          132
# type           19
# country        51
# area          481
# location      565
# activity      586
# name          220
# sex           572
# age          2987
# fatal_y_n       0
# time         3518
# species      3118
# dtype: int64

# %%
sns.barplot(data=df,x='location',y='species')
# Out:
# <Axes: xlabel='location', ylabel='species'>
# ) missing from font(s) DejaVu Sans.ing\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from font(s) DejaVu Sans.ing\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.histplot(data = df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.histplot(data = df, x='species')
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
df['sex']
# Out:
# 0       M
# 1       M
# 2       M
# 3       M
# 4       M
#        ..
# 6885    M
# 6886    M
# 6887    M
# 6888    M
# 6889    M
# Name: sex, Length: 6890, dtype: object

# %%
# df['sex'].fillna("M", inplace=True)
df['sex'].fillna(df['sex'].mode()[0], inplace=True)

# %%
# turini, miqdorini tekshirish

df['sex'].value_counts()
# Out:
# sex
# M        6102
# F         764
# N           2
# .           1
# M x 2       1
# lli         1
# Name: count, dtype: int64

# %%
# muayyan column (bu yerda species) ga access olish va ustida amallar bajarish
# buyerda bu kodining o'zi esa shunchaki value larni ko'rsatyapti xolos.

df['species']
# Out:
# 0       White shark
# 1          1m shark
# 2        Bull shark
# 3               NaN
# 4               NaN
#            ...
# 6885            NaN
# 6886            NaN
# 6887     Bull shark
# 6888            NaN
# 6889            NaN
# Name: species, Length: 6890, dtype: object

# %%
# turini tekshirish
# Masalan buyerda White shark 105 ta Tiger shark 89 ta

df['species'].value_counts()
# Out:
# species
# White shark                                                                                          192
# Shark involvement prior to death was not confirmed                                                   105
# Invalid                                                                                              102
# Shark involvement not confirmed                                                                       92
# Tiger shark                                                                                           89
#                                                                                                     ...
# 3 m [10'] gaffed shark                                                                                 1
# Raggedtooth shark, 2 m                                                                                 1
# Tooth fragment of a white shark recovered. Authorities believed shark was 6 m [20']  total length      1
# Shark involvement not confirmed; officials considered barracua                                         1
# Caribbean reef shark, 6'                                                                               1
# Name: count, Length: 1560, dtype: int64

# %%
# Missing value larni tekshirish

df.isnull().sum()
# Out:
# date          303
# year          132
# type           19
# country        51
# area          481
# location      565
# activity      586
# name          220
# sex             0
# age          2987
# fatal_y_n       0
# time         3518
# species      3118
# dtype: int64

# %%
# Missing value ni tekshirish (faqat bitta column)
# Buyereda species column tekshirilgan va 3118 ta missing value bor.

df['species'].isnull().sum()
# Out:
# np.int64(3118)

# %%
df['species']
# Out:
# 0       White shark
# 1          1m shark
# 2        Bull shark
# 3       White shark
# 4       White shark
#            ...
# 6885    White shark
# 6886    White shark
# 6887     Bull shark
# 6888    White shark
# 6889    White shark
# Name: species, Length: 6871, dtype: object

# %%
df['species'].fillna(df['species'].mode()[0], inplace=True)

# %%
print(df['species'].dtype)
# Out:
# object

# %%
df['species'].value_counts()
# Out:
# species
# White shark                                           3298
# Shark involvement prior to death was not confirmed     105
# Invalid                                                102
# Shark involvement not confirmed                         90
# Tiger shark                                             89
#                                                       ...
# Spinner shark or blacktip shark                          1
# Nurse shark, 4'                                          1
# Sandtiger shark  2'                                      1
# Tiger shark, 8 to 10 feet                                1
# White shark, 2.1 m [7']                                  1
# Name: count, Length: 1559, dtype: int64

# %%
# Checking the percentage of missing values to see how serious the issue is:

df.isnull().sum() / len(df) * 100
# Out:
# date         100.000000
# year           1.877456
# type           0.000000
# country        0.727696
# area           6.927667
# location       0.000000
# activity       8.455829
# name           0.000000
# sex            0.000000
# age            0.000000
# fatal_y_n      0.000000
# time           0.000000
# species        0.000000
# dtype: float64

# %%
df['age']
# Out:
# 0             46
# 1            NaN
# 2             38
# 3           25.0
# 4            NaN
#           ...
# 6885         NaN
# 6886         NaN
# 6887    13 or 14
# 6888         NaN
# 6889         NaN
# Name: age, Length: 6890, dtype: object

# %%
df.isnull().sum()
# Out:
# date          303
# year          132
# type           19
# country        51
# area          481
# location      565
# activity      586
# name          220
# sex             0
# age          2987
# fatal_y_n       0
# time         3518
# species      3118
# dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 16.0        89
# 19.0        89
# 17.0        88
# 17          84
# 15          83
#             ..
# Both 11      1
# Ca. 33       1
# 21 or 26     1
# 9 months     1
# 13 or 14     1
# Name: count, Length: 232, dtype: int64

# %%
# Fill with median

# df['age'].fillna(df['age'].median(), inplace=True)

# %%
# shu ustundagi missing valuelar miqdorini tekshirish

df['time'].isnull().sum()
# Out:
# np.int64(3518)

# %%
# unique values in the column

df['age'].unique()
# Out:
# array([46., 24., 38., 25., 26., 14., 53., 16., 17., 59., 60., 33.,  9.,
#        21., 37., 50.,  6., 57., 13., 19., 43., 12., 31., 32., 10., 47.,
#        20.,  7., 28., 42., 45., 30., 68.,  8., 34., 23., 18., 49., 27.,
#        52., 35.,  5., 15., 44., 39., 29., 48., 22., 36., 51., 58., 54.,
#        70., 11., 74., 40., 71., 63., 56., 62., 86., 61., 41., 78., 64.,
#        55., 65.,  3., 69., 66.,  1., 73., 72., 77., 81., 84., 75.,  4.,
#        87., 67., 82.])

# %%
# age ustunidagi raqamli bo'lmagan datalarni raqamliga o'zgartirish
# errors = coerce degani ikkita raqam berilgan bo'lsa uni berilmaganga almashtirish
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['time'] = pd.to_numeric(df['time'], errors='coerce')
df['date'] = pd.to_numeric(df['date'], errors='coerce')

# %%
df['age'].fillna(df['age'].median(),inplace=True)
# Out:
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\2790788646.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# date         6871
# year          129
# type            0
# country        50
# area          476
# location        0
# activity      581
# name            0
# sex             0
# age             0
# fatal_y_n       0
# time            0
# species         0
# dtype: int64

# %%
# Fix method, using a specific value to fill missing value

# df['name'].fillna('John', inplace=True)

# %%
df['name'].value_counts()
# Out:
# name
# male                                                            663
# female                                                          131
# Alice                                                            84
# John                                                             78
# Micheal                                                          58
#                                                                ...
# crew member of a pilot boat                                       1
# Ensign Bromwick                                                   1
# Samuel Jennings, a deserter from the British frigate Milford      1
# a ship's engineer                                                 1
# Charles Barclay                                                   1
# Name: count, Length: 5631, dtype: int64

# %%
df['name'].fillna('John', inplace=True)
# Out:
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\1886302966.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['name'].fillna('John', inplace=True)

# %%
df.isnull().sum()
# Out:
# date         6871
# year          129
# type            0
# country        50
# area          476
# location        0
# activity      581
# name            0
# sex             0
# age             0
# fatal_y_n       0
# time            0
# species         0
# dtype: int64

# %%
# column dagi missing value larni tashlab yuborish

df=df.dropna(subset=['type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6871 entries, 0 to 6889
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       0 non-null      float64
#  1   year       6742 non-null   float64
#  2   type       6871 non-null   object
#  3   country    6821 non-null   object
#  4   area       6395 non-null   object
#  5   location   6308 non-null   object
#  6   activity   6290 non-null   object
#  7   name       6871 non-null   object
#  8   sex        6871 non-null   object
#  9   age        6871 non-null   float64
#  10  fatal_y_n  6871 non-null   object
#  11  time       6 non-null      float64
#  12  species    3765 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 751.5+ KB

# %%
df.count()
# Out:
# date            0
# year         6742
# type         6871
# country      6821
# area         6395
# location     6871
# activity     6290
# name         6871
# sex          6871
# age          6871
# fatal_y_n    6871
# time         6871
# species      6871
# dtype: int64

# %%
df.shape[0]
# Out:
# 6871

# %%
#tushib qolganlarni bir joyga jamlash

# tushib_qolganlar=df.columns[df.isnull().any()]
#tushib_qolganlar

# %%
#tushib qolganlarni umumiy tashlab yuborish

# df=df.dropna(subset=tushib_qolganlar)

# %%
df.isnull().sum()
# Out:
# date         6871
# year          129
# type            0
# country        50
# area          476
# location      563
# activity      581
# name            0
# sex             0
# age             0
# fatal_y_n       0
# time         6865
# species      3106
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6871 entries, 0 to 6889
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       0 non-null      float64
#  1   year       6742 non-null   float64
#  2   type       6871 non-null   object
#  3   country    6821 non-null   object
#  4   area       6395 non-null   object
#  5   location   6308 non-null   object
#  6   activity   6290 non-null   object
#  7   name       6871 non-null   object
#  8   sex        6871 non-null   object
#  9   age        6871 non-null   float64
#  10  fatal_y_n  6871 non-null   object
#  11  time       6 non-null      float64
#  12  species    3765 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 751.5+ KB

# %%
df.count()
# Out:
# date            0
# year         6742
# type         6871
# country      6821
# area         6395
# location     6308
# activity     6290
# name         6871
# sex          6871
# age          6871
# fatal_y_n    6871
# time            6
# species      3765
# dtype: int64

# %% [markdown]
# Drop

# %%
#df=df.dropna(subset=['type'])
#df=df.dropna(subset=['age'])

# %%
# drop da bir qatorni yoki hamma qatorni tashlab yuborish mumkin
# birinchisi bir qatorni tashlash

#df=df.dropna(subset=['age'])
#df=df.dropna(subset=['species'])

#ikkinchisi umumiy

#missing_values = df.columns[df.isnull().any()]
#df=df.dropna(subset=missing_values)
#missing_values=df.columns[df.isnull().any()]
#df=df.dropna(subset=missing_values)

# %% [markdown]
# Fix

# %%
# ustunni qat'iy qiymat bilan to'ldirish

#df['species'].fillna('White shark', inplace=True)
#df['sex'].fillna('female', inplace=True)
#df['age'].fillna(20, inplace=True)

# %% [markdown]
# Mean

# %%
# mean odatda raqamlar bilan ishlaydi va raqmli dataning o'rta hisboni olib value yo'q joylarni to'lidiradi

df['age'].fillna(df['age'].mean(), inplace=True)
df['date'].fillna(df['date'].mean(), inplace=True)
df['time'].fillna(df['time'].mean(), inplace=True)


# kodlar raqamli emas string yoki object typeda bo'lgani uchun ishlamadi va ularni quyidagi kodlar orqali raqamli formatga aylantirildi

df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['time'] = pd.to_datetime(df['time'], errors= "coerce")
df['date']=pd.to_datetime(df['date'], errors='coerce')
# Out:
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\3561826525.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\3561826525.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['date'].fillna(df['date'].mean(), inplace=True)
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\3561826525.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['time'].fillna(df['time'].mean(), inplace=True)

# %% [markdown]
# Mode

# %%
# mode object datatypelar bilan ishlaydi va eng ko'p kelgan class bilan missing-valuelarni to'ldiradi

df['name'].fillna(df['name'].mode()[0], inplace=True)
df['species'].fillna(df['species'].mode()[0], inplace=True)
df['location'].fillna(df['location'].mode()[0], inplace=True)
# Out:
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\4124772030.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['name'].fillna(df['name'].mode()[0], inplace=True)
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\4124772030.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['species'].fillna(df['species'].mode()[0], inplace=True)
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\4124772030.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['location'].fillna(df['location'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6871 entries, 0 to 6889
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       0 non-null      datetime64[ns]
#  1   year       6742 non-null   float64
#  2   type       6871 non-null   object
#  3   country    6821 non-null   object
#  4   area       6395 non-null   object
#  5   location   6871 non-null   object
#  6   activity   6290 non-null   object
#  7   name       6871 non-null   object
#  8   sex        6871 non-null   object
#  9   age        6871 non-null   float64
#  10  fatal_y_n  6871 non-null   object
#  11  time       6871 non-null   datetime64[ns]
#  12  species    6871 non-null   object
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 751.5+ KB

# %% [markdown]
# Median

# %%
# median o'rta postiondagi value qiymatini topadi va missing valuelarni o'sha bilan to'ldiradi.

df['age'].fillna(df['age'].median(), inplace= True)
# Out:
# C:\Users\Saidabrorkhon\AppData\Local\Temp\ipykernel_25188\2101748260.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace= True)
