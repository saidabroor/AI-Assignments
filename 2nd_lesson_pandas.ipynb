# %% [markdown]
# # Kutubxonalar

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('telefon turini aniqlash2.csv') #datani o'rnatish

# %%
df #datani umumiy ko'rish
# Out:
#       battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0                 842       0                 2.2                   0
# 1                1021       1                 0.5                   1
# 2                 563       1                 0.5                   1
# 3                 615       1                 2.5                   0
# 4                1821       1                 1.2                   0
# ...               ...     ...                 ...                 ...
# 1996              794       1                 0.5                   1
# 1997             1965       1                 2.6                   1
# 1998             1911       0                 0.9                   1
# 1999             1512       0                 0.9                   0
# 2000              510       1                 2.0                   1
#
#       Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi      Rangi  Vazni  ...  \
# ...

# %%
df.head()  # boshidan beshta qatorni ko'rish
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi      Rangi  Vazni  ...  \
# 0            1   0             7               0.6      Qizil    188  ...
# 1            0   1            53               0.7     Yashil    136  ...
# 2            2   1            41               0.9      Sariq    145  ...
# 3            0   0            10               0.8  Jigarrang    131  ...
# 4           13   1            44               0.6         Oq    141  ...
#
#    Qurilma ekran kengligi(pix)   ram  Qurilma xajmi(cm)  \
# 0                        756.0  2549                9.0
# ...

# %%
df.tail()
# Out:
#       battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 1996              794       1                 0.5                   1
# 1997             1965       1                 2.6                   1
# 1998             1911       0                 0.9                   1
# 1999             1512       0                 0.9                   0
# 2000              510       1                 2.0                   1
#
#       Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi Rangi  Vazni  ...  \
# 1996            0   1             2               0.8  Qora    106  ...
# 1997            0   0            39               0.2  Qora    187  ...
# 1998            1   1            36               0.7  Qora    108  ...
# 1999            4   1            46               0.1  Qora    145  ...
# 2000            5   1            45               0.9  Qora    168  ...
#
#       Qurilma ekran kengligi(pix)   ram  Qurilma xajmi(cm)  \
# ...

# %%
df.info() # to'liq ma'lumot olish
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2001 non-null   int64
#  1   blutus                         2001 non-null   int64
#  2   protsessor_tezligi             2001 non-null   float64
#  3   ikkita simkartalik             2001 non-null   int64
#  4   Oldi_kamera                    2001 non-null   int64
#  5   4G                             2001 non-null   int64
#  6   Ichki_xotira                   2001 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          2001 non-null   object
#  9   Vazni                          2001 non-null   int64
#  10  Protsessor yadrolari soni      2000 non-null   float64
#  11  Asosiy kamera                  1999 non-null   float64
# ...

# %%
# ustunlarning o'zini ko'rish (qavs bo'lmaydi)

df.columns
# Out:
# Index(['battereya_hajmi', 'blutus', 'protsessor_tezligi', 'ikkita simkartalik',
#        'Oldi_kamera', '4G', 'Ichki_xotira', 'tel_ingichgaligi', 'Rangi',
#        'Vazni', 'Protsessor yadrolari soni', 'Asosiy kamera',
#        'Qurilma xajmi(pix)', 'Qurilma ekran kengligi(pix)', 'ram',
#        'Qurilma xajmi(cm)', 'Qurilma ekran kengligi(cm)',
#        'Bir_quvvatlashdagi gaplashish', '3g', 'Qurilma xajmi(pix).1',
#        'sensorli', 'wifi', 'telefon_turi'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['battereya_hajmi',
#  'blutus',
#  'protsessor_tezligi',
#  'ikkita simkartalik',
#  'Oldi_kamera',
#  '4G',
#  'Ichki_xotira',
#  'tel_ingichgaligi',
#  'Rangi',
#  'Vazni',
#  'Protsessor yadrolari soni',
#  'Asosiy kamera',
#  'Qurilma xajmi(pix)',
#  'Qurilma ekran kengligi(pix)',
#  'ram',
#  'Qurilma xajmi(cm)',
#  'Qurilma ekran kengligi(cm)',
#  'Bir_quvvatlashdagi gaplashish',
#  '3g',
#  'Qurilma xajmi(pix).1',
#  'sensorli',
#  'wifi',
#  'telefon_turi']

# %%
df['Rangi']
# Out:
# 0           Qizil
# 1          Yashil
# 2           Sariq
# 3       Jigarrang
# 4              Oq
#           ...
# 1996         Qora
# 1997         Qora
# 1998         Qora
# 1999         Qora
# 2000         Qora
# Name: Rangi, Length: 2001, dtype: object

# %%
df['Rangi'].value_counts()  # Har bir classga taaluqli elementlar soni
# Out:
# Rangi
# Qora         1989
# Yashil          7
# Oq              2
# Qizil           1
# Jigarrang       1
# Sariq           1
# Name: count, dtype: int64

# %%
# statistik tahlil

df.describe()
# Out:
#        battereya_hajmi       blutus  protsessor_tezligi  ikkita simkartalik  \
# count      2001.000000  2001.000000         2001.000000         2001.000000
# mean       1238.876062     0.494753            1.521739            0.509745
# std         439.599414     0.500097            0.816120            0.500030
# min         501.000000     0.000000            0.500000            0.000000
# 25%         852.000000     0.000000            0.700000            0.000000
# 50%        1227.000000     0.000000            1.500000            1.000000
# 75%        1616.000000     1.000000            2.200000            1.000000
# max        1998.000000     1.000000            3.000000            1.000000
#
#        Oldi_kamera           4G  Ichki_xotira  tel_ingichgaligi        Vazni  \
# count  2001.000000  2001.000000   2001.000000       1998.000000  2001.000000
# mean      4.307346     0.521239     32.042479          0.501952   140.272364
# ...

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 8.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------------------------------- - 2.1/2.2 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------------------------- -------- 2.1/2.6 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 7.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.style.use('_mpl-gallery')

# make data:
x = 0.5 + np.arange(8)
y = [4.8, 5.5, 3.5, 4.6, 6.5, 6.6, 2.6, 3.0]

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example planets dataset
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=planets,
    x="distance", y="orbital_period",
    hue="year", size="mass",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
#tushib qolgan qiymatlarni aniqlash

df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 3
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
sns.barplot(data = df, x='Vazni',y='telefon_turi')
# Out:
# <Axes: xlabel='Vazni', ylabel='telefon_turi'>

# %%
sns.histplot(data = df, x='telefon_turi')
# Out:
# <Axes: xlabel='telefon_turi', ylabel='Count'>

# %%
df['telefon_turi'].value_counts()
# Out:
# telefon_turi
# 0    501
# 1    500
# 2    500
# 3    500
# Name: count, dtype: int64
